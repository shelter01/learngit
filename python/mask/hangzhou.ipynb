# %%
import geohash
import pandas as pd
import numpy as np
import random
import math
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline
table = pd.read_csv('d:/sjw/dsjw/experimental/regression/point3000.csv',header=None,low_memory=False)
geo = table.values.tolist()
dec = []

# %%
for x in range(len(geo)):
    dec.append(geohash.decode(geohash.encode(geo[x][1],geo[x][0],8)))

# %%
dec
# Out:
# [('30.269', '120.165'),
#  ('30.267', '120.165'),
#  ('30.267', '120.165'),
#  ('30.27', '120.166'),
#  ('30.272', '120.165'),
#  ('30.267', '120.165'),
#  ('30.27', '120.166'),
#  ('30.268', '120.166'),
#  ('30.269', '120.166'),
#  ('30.271', '120.166'),
#  ('30.269', '120.166'),
#  ('30.271', '120.166'),
#  ('30.271', '120.166'),
#  ('30.295', '120.165'),
#  ('30.295', '120.165'),
#  ('30.293', '120.165'),
#  ('30.295', '120.166'),
#  ('30.298', '120.166'),
#  ('30.295', '120.166'),
#  ('30.297', '120.166'),
#  ('30.299', '120.166'),
#  ('30.295', '120.166'),
#  ('30.3', '120.166'),
#  ('30.3', '120.166'),
#  ('30.293', '120.165'),
#  ('30.295', '120.167'),
#  ('30.295', '120.168'),
#  ('30.293', '120.167'),
#  ('30.292', '120.167'),
#  ('30.295', '120.168'),
#  ('30.293', '120.168'),
#  ('30.293', '120.168'),
#  ('30.292', '120.169'),
#  ('30.299', '120.167'),
#  ('30.3', '120.167'),
#  ('30.299', '120.167'),
#  ('30.3', '120.167'),
#  ('30.291', '120.166'),
# ...
