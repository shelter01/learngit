# %%
import geohash
import pandas as pd
import numpy as np
import random
import math
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
table = pd.read_csv('C:/Users/sjw/Desktop/paper/data/train.csv',header=None,low_memory=False)

# %%
geo = table[5][1:].values.tolist()
dec = []

# %%
for x in range(len(geo)):
    dec.append(list(geohash.decode(geo[x])))

# %%
dec
# Out:
# [['40.1', '116.29'],
#  ['39.79', '116.33'],
#  ['39.88', '116.54'],
#  ['39.77', '116.16'],
#  ['39.96', '116.39'],
#  ['39.99', '116.47'],
#  ['39.75', '116.56'],
#  ['39.97', '116.28'],
#  ['39.85', '116.39'],
#  ['39.89', '116.33'],
#  ['39.86', '116.3'],
#  ['39.85', '116.43'],
#  ['39.85', '116.31'],
#  ['39.94', '116.45'],
#  ['39.95', '116.4'],
#  ['39.91', '116.5'],
#  ['39.89', '116.43'],
#  ['39.81', '116.2'],
#  ['39.79', '116.48'],
#  ['39.91', '116.28'],
#  ['39.9', '116.69'],
#  ['39.85', '116.43'],
#  ['39.95', '116.42'],
#  ['39.92', '116.42'],
#  ['39.94', '116.53'],
#  ['39.98', '116.25'],
#  ['39.93', '116.58'],
#  ['39.87', '116.54'],
#  ['39.96', '116.29'],
#  ['39.9', '116.27'],
#  ['39.72', '116.16'],
#  ['39.84', '116.3'],
#  ['40.', '116.47'],
#  ['39.87', '116.65'],
#  ['39.76', '116.51'],
#  ['39.93', '116.41'],
#  ['39.88', '116.39'],
#  ['40.', '116.29'],
#  ['39.92', '116.2'],
#  ['39.91', '116.58'],
#  ['39.94', '116.13'],
#  ['39.98', '116.25'],
# ...

# %%
geohash.decode(geohash.encode(31.0780026509224,121.093984006447,7))
# Out:
# ('31.08', '121.09')
